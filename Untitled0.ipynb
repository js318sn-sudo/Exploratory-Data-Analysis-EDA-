# %% [markdown]
# <a href="https://colab.research.google.com/github/js318sn-sudo/Exploratory-Data-Analysis-EDA-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load Dataset
df = pd.read_csv("sample_data.csv")

# Display Dataset
print("Dataset")
print(df)

# First 5 Rows
print("\nFirst 5 Rows")
print(df.head())

# Dataset Information
print("\nDataset Information")
print(df.info())

# Summary Statistics
print("\nSummary Statistics")
print(df.describe())

# Dataset Shape
print("\nDataset Shape")
print(df.shape)

# Missing Values
print("\nMissing Values")
print(df.isnull().sum())

# Duplicate Values
print("\nDuplicate Values")
print(df.duplicated().sum())

# Data Types
print("\nData Types")
print(df.dtypes)

# Histogram
df.hist(figsize=(10,8))
plt.suptitle("Histogram")
plt.show()

# Boxplot
plt.figure(figsize=(8,5))
sns.boxplot(data=df.select_dtypes(include=np.number))
plt.title("Boxplot")
plt.show()

# Heatmap
plt.figure(figsize=(8,5))
sns.heatmap(
    df.select_dtypes(include=np.number).corr(),
    annot=True,
    cmap="coolwarm"
)
plt.title("Correlation Heatmap")
plt.show()

# Countplot
sns.countplot(x="Department", data=df)
plt.title("Department Count")
plt.show()

# Pairplot
sns.pairplot(df.select_dtypes(include=np.number))
plt.show()

# Insights
print("\nInsights")
print("1. IT department employees tend to have higher salaries.")
print("2. Experience positively affects salary.")
print("3. Performance scores improve with experience.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4887/1122143894.py in <cell line: 0>()
#       6
#       7 # Load Dataset
# ----> 8 df = pd.read_csv("sample_data.csv")
#       9
#      10 # Display Dataset
#
# ...

# %%
# Exploratory Data Analysis (EDA) Project

# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Plot Style
sns.set_style("whitegrid")

# Load Dataset
# ERROR: The file 'sample_data.csv' was not found. Please upload the 'sample_data.csv' file to your Colab environment
# or provide the correct path to your dataset.
# Example: from google.colab import files
#          uploaded = files.upload()
#          df = pd.read_csv('sample_data.csv') # if uploaded to current directory
# As a temporary workaround to unblock, let's create a dummy DataFrame.
data = {
    'Department': ['IT', 'HR', 'IT', 'Sales', 'HR', 'IT', 'Sales', 'HR'],
    'Experience': [5, 2, 7, 3, 4, 6, 2, 5],
    'Salary': [70000, 45000, 80000, 55000, 50000, 75000, 50000, 60000],
    'Performance_Score': [85, 70, 90, 75, 80, 88, 72, 82]
}
df = pd.DataFrame(data)

# Display Dataset
print("Dataset")
print(df)

# First 5 Rows
print("\nFirst 5 Rows")
print(df.head())

# Dataset Information
print("\nDataset Information")
df.info()

# Dataset Shape
print("\nDataset Shape")
print(df.shape)

# Column Names
print("\nColumn Names")
print(df.columns.tolist())

# Missing Values
print("\nMissing Values")
print(df.isnull().sum())

# Duplicate Values
print("\nDuplicate Values")
print(df.duplicated().sum())

# Data Types
print("\nData Types")
print(df.dtypes)

# Summary Statistics
print("\nSummary Statistics")
print(df.describe())

# Histogram
df.hist(figsize=(10,8))
plt.suptitle("Histogram of Numerical Features")
plt.show()

# Boxplot
plt.figure(figsize=(8,5))
sns.boxplot(data=df.select_dtypes(include=np.number))
plt.title("Boxplot")
plt.show()

# Correlation Heatmap
plt.figure(figsize=(8,5))

correlation = df.select_dtypes(include=np.number).corr()

sns.heatmap(
    correlation,
    annot=True,
    cmap="coolwarm"
)

plt.title("Correlation Heatmap")
plt.show()

# Countplot
plt.figure(figsize=(7,5))

sns.countplot(x="Department", data=df)

plt.title("Department Count")
plt.show()

# Pairplot
sns.pairplot(df.select_dtypes(include=np.number))
plt.show()

# Insights
print("\nInsights")
print("1. IT department employees tend to have higher salaries.")
print("2. Experience positively affects salary.")
print("3. Performance scores improve with experience.")
print("4. No missing values are present in the dataset.")
print("5. No duplicate records were found.")
# Out:
# Dataset
#   Department  Experience  Salary  Performance_Score
# 0         IT           5   70000                 85
# 1         HR           2   45000                 70
# 2         IT           7   80000                 90
# 3      Sales           3   55000                 75
# 4         HR           4   50000                 80
# 5         IT           6   75000                 88
# 6      Sales           2   50000                 72
# 7         HR           5   60000                 82
#
# First 5 Rows
#   Department  Experience  Salary  Performance_Score
# 0         IT           5   70000                 85
# 1         HR           2   45000                 70
# 2         IT           7   80000                 90
# 3      Sales           3   55000                 75
# 4         HR           4   50000                 80
#
# Dataset Information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
# ...
